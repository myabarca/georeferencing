# %%
# import pandas library. install first if not yet installed

# %%
import pandas as pd

# %%
# load data into dataframes. 
# one dataframe has locationIDs with georeferenced data (georeferencedIDs)
# one has all of your collection's locationIDs (allLocationIDs)

# %%
allLocationIDs = pd.read_csv('allLocationIDs_publicSample.csv')

georeferencedIDs = pd.read_csv('georeferencedLocationIDs_publicSample.csv')

# %%
# check to see how data loaded
allLocationIDs.head()
# Out:
#   institutionCode collectionCode  locationID    recordedBy verbatimEventDate  \
# 0            CASG         Fossil           1  Bruce Martin               NaN
# 1            CASG         Fossil           2  Bruce Martin               NaN
# 2            CASG         Fossil           3  Bruce Martin               NaN
# 3            CASG         Fossil           4  Bruce Martin               NaN
# 4            CASG         Fossil           5  Bruce Martin               NaN
#
#        continent country stateProvince county fieldNumber  ...  \
# 0  North America     USA        Oregon   Coos         NaN  ...
# 1  North America     USA        Oregon   Coos         NaN  ...
# 2  North America     USA        Oregon   Coos         NaN  ...
# 3  North America     USA        Oregon   Coos         NaN  ...
# 4  North America     USA        Oregon   Coos         NaN  ...
#
#   earliestEpochOrLowestSeries latestEpochOrHighestSeries  \
# 0                    Pliocene                   Pliocene
# 1                    Pliocene                   Pliocene
# 2                    Pliocene                   Pliocene
# 3                     Miocene                    Miocene
# 4                    Pliocene                   Pliocene
#
#   earliestAgeOrLowestStage latestAgeOrHighestStage stratGroup stratFormation  \
# 0                      NaN                     NaN        NaN            NaN
# 1                      NaN                     NaN        NaN            NaN
# 2                      NaN                     NaN        NaN            NaN
# 3                      NaN                     NaN        NaN         Empire
# 4                      NaN                     NaN        NaN         Empire
#
#   stratMember stratBed bioZone  lithology
# 0         NaN      NaN     NaN  sandstone
# 1         NaN      NaN     NaN        NaN
# 2         NaN      NaN     NaN        NaN
# 3         NaN      NaN     NaN        NaN
# 4         NaN      NaN     NaN        NaN
#
# [5 rows x 24 columns]

# %%
# check to see how data loaded
georeferencedIDs.head()
# Out:
#    locationID georeferenceVerificationStatus georeferencedBy  \
# 0           1                      corrected        nafamoso
# 1           2                      corrected        nafamoso
# 2           3                      corrected        nafamoso
# 3           4                      corrected        nafamoso
# 4           5                      corrected         Viekson
#
#      georeferencedDate georeferenceRemarks geodeticDatum georeferenceProtocol  \
# 0  2016-12-23 21:47:01                 NaN           NaN                  NaN
# 1  2016-12-23 21:55:36                 NaN           NaN                  NaN
# 2  2016-12-23 21:51:24                 NaN           NaN                  NaN
# 3  2016-12-23 21:55:04                 NaN           NaN                  NaN
# 4  2016-08-29 16:17:09                 NaN           NaN                  NaN
#
#   georeferenceSources  decimalLongitude  decimalLatitude  \
# 0                 NaN       -124.287000        43.373400
# 1                 NaN       -124.307100        43.358900
# 2                 NaN       -124.307100        43.358900
# 3                 NaN       -124.307100        43.358900
# 4                 NaN       -124.360208        43.342115
#
#    coordinateUncertaintyInMeters correctedUncertaintyRadiusCircularPolygonWKT  \
# 0                          969.0                                          NaN
# 1                          969.0                                          NaN
# 2                          969.0                                          NaN
# 3                          969.0                                          NaN
# 4                          250.0                                          NaN
#
#   correctedUncertaintyPolygonWKT         dateImported
# 0                            NaN  2021-04-22 12:37:03
# 1                            NaN  2021-04-22 12:37:03
# 2                            NaN  2021-04-22 12:37:03
# 3                            NaN  2021-04-22 12:37:03
# 4                            NaN  2021-04-22 12:37:03

# %%
# check datatypes and structure of original dataframes
allLocationIDs.info()
georeferencedIDs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8506 entries, 0 to 8505
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   institutionCode               8498 non-null   object
#  1   collectionCode                8506 non-null   object
#  2   locationID                    8506 non-null   int64
#  3   recordedBy                    5844 non-null   object
#  4   verbatimEventDate             3609 non-null   object
#  5   continent                     7722 non-null   object
#  6   country                       8456 non-null   object
#  7   stateProvince                 7579 non-null   object
#  8   county                        5190 non-null   object
#  9   fieldNumber                   2243 non-null   object
#  10  earliestEraOrLowestErathem    7175 non-null   object
#  11  latestEraOrHighestErathem     7175 non-null   object
#  12  earliestPeriodOrLowestSystem  7033 non-null   object
#  13  latestPeriodOrHighestSystem   7032 non-null   object
#  14  earliestEpochOrLowestSeries   4644 non-null   object
#  15  latestEpochOrHighestSeries    4645 non-null   object
#  16  earliestAgeOrLowestStage      633 non-null    object
#  17  latestAgeOrHighestStage       631 non-null    object
#  18  stratGroup                    209 non-null    object
#  19  stratFormation                3558 non-null   object
#  20  stratMember                   167 non-null    object
#  21  stratBed                      13 non-null     object
#  22  bioZone                       20 non-null     object
#  23  lithology                     941 non-null    object
# dtypes: int64(1), object(23)
# memory usage: 1.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110 entries, 0 to 1109
# Data columns (total 14 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   locationID                                    1110 non-null   int64
#  1   georeferenceVerificationStatus                1057 non-null   object
#  2   georeferencedBy                               519 non-null    object
#  3   georeferencedDate                             505 non-null    object
#  4   georeferenceRemarks                           831 non-null    object
#  5   geodeticDatum                                 680 non-null    object
#  6   georeferenceProtocol                          679 non-null    object
#  7   georeferenceSources                           679 non-null    object
#  8   decimalLongitude                              1110 non-null   float64
#  9   decimalLatitude                               1110 non-null   float64
#  10  coordinateUncertaintyInMeters                 520 non-null    float64
#  11  correctedUncertaintyRadiusCircularPolygonWKT  217 non-null    object
#  12  correctedUncertaintyPolygonWKT                13 non-null     object
#  13  dateImported                                  1110 non-null   object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 121.5+ KB

# %%
# the range and number of non-null locationIDs match, which means there are no null locationIDs in our data
# this is important because missing values can cause errors

# %%
# make list of georeferenced locationIDs to compare to all locationIDs
georefLocIDs = georeferencedIDs['locationID'].to_list()

# %%
# check to make sure list of IDs is the same as range of georeference df
print (len(georefLocIDs))
# Out:
# 1110

# %%
# .query() uses syntax similar to SQL
queryMethod = allLocationIDs.query("locationID not in @georefLocIDs")

# %%
# we can see that the range went from 8506 (in allLocationIDs df) to 7396
# so 1110 have been taken out and placed into the queryMethod df
# this is equal to the 1110 range in the georef df
# if the numbers are not equal, you have either have duplicate records or missing records
queryMethod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7396 entries, 26 to 8505
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   institutionCode               7391 non-null   object
#  1   collectionCode                7396 non-null   object
#  2   locationID                    7396 non-null   int64
#  3   recordedBy                    5065 non-null   object
#  4   verbatimEventDate             3139 non-null   object
#  5   continent                     6612 non-null   object
#  6   country                       7346 non-null   object
#  7   stateProvince                 6469 non-null   object
#  8   county                        4094 non-null   object
#  9   fieldNumber                   1979 non-null   object
#  10  earliestEraOrLowestErathem    6188 non-null   object
#  11  latestEraOrHighestErathem     6188 non-null   object
#  12  earliestPeriodOrLowestSystem  6069 non-null   object
#  13  latestPeriodOrHighestSystem   6068 non-null   object
#  14  earliestEpochOrLowestSeries   3697 non-null   object
#  15  latestEpochOrHighestSeries    3698 non-null   object
#  16  earliestAgeOrLowestStage      624 non-null    object
#  17  latestAgeOrHighestStage       622 non-null    object
#  18  stratGroup                    178 non-null    object
#  19  stratFormation                2995 non-null   object
#  20  stratMember                   157 non-null    object
#  21  stratBed                      13 non-null     object
#  22  bioZone                       19 non-null     object
#  23  lithology                     721 non-null    object
# dtypes: int64(1), object(23)
# memory usage: 1.4+ MB

# %%
# an alternative to the queryMethod is the .isin() method
# we used the ~ to indicate "not in"
isInMethod = allLocationIDs[~allLocationIDs['locationID'].isin(georefLocIDs)]

# %%
# isin() gives the same size df as queryMethod.
# either df can be used to save a new checklist to csv
isInMethod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7396 entries, 26 to 8505
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   institutionCode               7391 non-null   object
#  1   collectionCode                7396 non-null   object
#  2   locationID                    7396 non-null   int64
#  3   recordedBy                    5065 non-null   object
#  4   verbatimEventDate             3139 non-null   object
#  5   continent                     6612 non-null   object
#  6   country                       7346 non-null   object
#  7   stateProvince                 6469 non-null   object
#  8   county                        4094 non-null   object
#  9   fieldNumber                   1979 non-null   object
#  10  earliestEraOrLowestErathem    6188 non-null   object
#  11  latestEraOrHighestErathem     6188 non-null   object
#  12  earliestPeriodOrLowestSystem  6069 non-null   object
#  13  latestPeriodOrHighestSystem   6068 non-null   object
#  14  earliestEpochOrLowestSeries   3697 non-null   object
#  15  latestEpochOrHighestSeries    3698 non-null   object
#  16  earliestAgeOrLowestStage      624 non-null    object
#  17  latestAgeOrHighestStage       622 non-null    object
#  18  stratGroup                    178 non-null    object
#  19  stratFormation                2995 non-null   object
#  20  stratMember                   157 non-null    object
#  21  stratBed                      13 non-null     object
#  22  bioZone                       19 non-null     object
#  23  lithology                     721 non-null    object
# dtypes: int64(1), object(23)
# memory usage: 1.4+ MB

# %%
locsToBeGeoreferenced = queryMethod

# %%
locsToBeGeoreferenced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7396 entries, 26 to 8505
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   institutionCode               7391 non-null   object
#  1   collectionCode                7396 non-null   object
#  2   locationID                    7396 non-null   int64
#  3   recordedBy                    5065 non-null   object
#  4   verbatimEventDate             3139 non-null   object
#  5   continent                     6612 non-null   object
#  6   country                       7346 non-null   object
#  7   stateProvince                 6469 non-null   object
#  8   county                        4094 non-null   object
#  9   fieldNumber                   1979 non-null   object
#  10  earliestEraOrLowestErathem    6188 non-null   object
#  11  latestEraOrHighestErathem     6188 non-null   object
#  12  earliestPeriodOrLowestSystem  6069 non-null   object
#  13  latestPeriodOrHighestSystem   6068 non-null   object
#  14  earliestEpochOrLowestSeries   3697 non-null   object
#  15  latestEpochOrHighestSeries    3698 non-null   object
#  16  earliestAgeOrLowestStage      624 non-null    object
#  17  latestAgeOrHighestStage       622 non-null    object
#  18  stratGroup                    178 non-null    object
#  19  stratFormation                2995 non-null   object
#  20  stratMember                   157 non-null    object
#  21  stratBed                      13 non-null     object
#  22  bioZone                       19 non-null     object
#  23  lithology                     721 non-null    object
# dtypes: int64(1), object(23)
# memory usage: 1.4+ MB

# %%
# save to csv to use as new georeferencing list
# df.to_csv('filename.csv', index=False)
# index = False means the df index wont be saved as new column in csv, 
# which is fine bc it's arbitrary in this case

# %%
locsToBeGeoreferenced.to_csv('newGeoreferenceList.csv', index=False)
