# %%
# need to install folium and pandas if you don't have them already installed
import folium
import pandas as pd

# %%
# replace filename in "" with your file's name. 
# also make sure it's in the same folder as this jupyter notebook,
# or wherever your code is stored
df = pd.read_csv("localityDataWithGeorefData-samplePublic.csv")

# %%
# peek into a couple rows of your data
df.head()
# Out:
#    locationID  decimalLongitude_x  decimalLatitude_x  \
# 0           1         -124.287000          43.373400
# 1           2         -124.307100          43.358900
# 2           3         -124.307100          43.358900
# 3           4         -124.307100          43.358900
# 4           5         -124.360208          43.342115
#
#    coordinateUncertaintyInMeters      continent country stateProvince county  \
# 0                          969.0  North America     USA        Oregon   Coos
# 1                          969.0  North America     USA        Oregon   Coos
# 2                          969.0  North America     USA        Oregon   Coos
# 3                          969.0  North America     USA        Oregon   Coos
# 4                          250.0  North America     USA        Oregon   Coos
#
#                                            locality  georeferenceRemarks
# 0  Coos Bay, 100 yards north of the southwest cor...                 NaN
# ...

# %%
# need strings for content to appear in tooltip in map
df['locationID'] = df['locationID'].apply(str)
df['georeferenceRemarks']=df['georeferenceRemarks'].apply(str)

# %%
# plotting a single point based on our csv data

# %%
# store the first row as your point

# %%
#point= df.loc[0]

# %%
# folium.Marker(
#     location=[point['decimalLatitude'], point['decimalLongitude']]

# ).add_to(map)

# map
# works for single points, but want to iterate over all columns to make markers for all points

# %%
# mapping all the points in your csv through iterration

# %%
# location=[40.43148077979194, -121.6627849541342], 
# zoom_start=5 just sets a default map view and zoom. this can be customized

# %%
map = folium.Map(
location=[40.43148077979194, -121.6627849541342], 
zoom_start=5
)

for i, point in df.iterrows():
    #iterrows stores the row index in i, and stores the row in point
    folium.Marker(
    location=[point['decimalLatitude_x'], point['decimalLongitude_x']], 
    popup='<strong>Remarks: </strong><br>'+ point['georeferenceRemarks'],
    tooltip='<strong>locationID: </strong><br>'+ point['locationID']
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# save your map with 'map name'.save('filename.html')

# %%
# map.save('CAS-records-georeferenced.html')

# %%
# the blocks below can you help you see if your coordinates are plotting at least in the same state as your locality strings
# these are some examples from our dataset, 
# but you can change the filters to help you troubleshoot your own unique data

# %%
# df = df[df['stateProvince']== 'Washington']
# all plotting in WA, so looks okay at WA state level

# %%
# df = df[df['stateProvince']== 'Oregon']
# all plotting in OR, so looks okay at OR state level

# %%
# df = df[df['stateProvince']== 'California']
# okay except for 7039, which was way out in pacific ocean. - was missing latitude. corrected.

# %%
# df = df[df['stateProvince'] == 'Baja California']
# 36807 was mapping in LA County but was listed as Baja California
# error was that the allTopo input was for loc 36827, not 36807. data entry error, corrected. 
# good now. no more Baja CA locs
